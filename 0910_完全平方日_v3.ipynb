# %% [markdown]
# <a href="https://colab.research.google.com/github/789jacobis/python_learning/blob/main/0910_%E5%AE%8C%E5%85%A8%E5%B9%B3%E6%96%B9%E6%97%A5_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
basic_number = 4500
i = 0
count = 0

def check_leap_year(year):
    if year % 400 == 0:
        return True
    elif year % 100 == 0:
        return False
    elif year % 4 == 0:
        return True
    else:
        return False

def check_is_legal(year, month, day):
    if month in [1, 3, 5, 7, 8, 10, 12]:
        if 1 <= day <= 31:
            return True
    elif month in [4, 6, 9, 11]:
        if 1 <= day <= 30:
            return True
    elif month == 2:
        if check_leap_year(year):
            if 1 <= day <= 29:
                return True
        else:
            if 1 <= day <= 28:
                return True
    return False


while count < 10:
    test_date = (basic_number + i) ** 2
    year = test_date // 10000
    month = (test_date // 100) % 100
    day = test_date % 100
    # 如果日期合法
    if check_is_legal(year, month, day):
        print(f"{test_date}這一天是完全平方日")
        count += 1
    i += 1
# Out:
# 20720704這一天是完全平方日
# 20930625這一天是完全平方日
# 21150801這一天是完全平方日
# 21390625這一天是完全平方日
# 21520321這一天是完全平方日
# 21641104這一天是完全平方日
# 21650409這一天是完全平方日
# 21790224這一天是完全平方日
# 21921124這一天是完全平方日
# 22071204這一天是完全平方日
