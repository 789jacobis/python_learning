# %% [markdown]
# <a href="https://colab.research.google.com/github/789jacobis/python_learning/blob/main/0917_oxoxo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(2):
    print(i+1)
    for j in range(3):
        print("hello")
# Out:
# 1
# hello
# hello
# hello
# 2
# hello
# hello
# hello

# %%
# for i in range(4):
#     for j in range(5):
#         if (j+i) %2 == 0:
#             print("o", end="")
#         else:
#             print("x", end="")
#     print()

for i in range(4):
    for j in range(6):
        if (j+i) %3 == 0:
            print("1", end="")
        elif (j+i) %3 == 1:
            print("2", end="")
        else:
            print("3", end="")

    print()
# Out:
# 123123
# 231231
# 312312
# 123123

# %%
for i in range(4):
    line = ""
    for j in range(5):
        if (j + i) % 3 == 0:
            line = line + "o"
        elif (j + i) % 3 == 1:
            line = line + "x"
        elif (j + i) % 3 == 2:
            line = line + "!"
    print(line)

print()

symbols = ["o", "x", "!"]
for i in range(4):
    line = ""
    for j in range(5):
        pos = (j + i) % len(symbols)
        line = line + symbols[pos]
    print(line)
# Out:
# ox!ox
# x!ox!
# !ox!o
# ox!ox
#
# ox!ox
# x!ox!
# !ox!o
# ox!ox

# %%
#ABCDABCD
#BCDABCDA
#CDABCDAB
#DABCDABC

list1 = ["A", "B", "C", "D", "E"]

for i in range(len(list1)):
    for j in range(len(list1)*2):
        print(list1[(i+j)%len(list1)], end="")
    print()

# i=0, j=0 → list1[(0+0)%5] = list1[0] = A → ABCDEABCDE
# i=1, j=0 → list1[(1+0)%5] = list1[1] = B → BCDEABCDEA
# i=2, j=0 → list1[(2+0)%5] = list1[2] = C → CDEABCDEAB
# i=3, j=0 → list1[(3+0)%5] = list1[3] = D → DEABCDEABC
# i=4, j=0 → list1[(4+0)%5] = list1[4] = E → EABCDEABCD

# 每列 j 都會從 0 跑到 9
# (i+j)%5 讓索引超過 4 後重新回到 0
# Out:
# ABCDEABCDE
# BCDEABCDEA
# CDEABCDEAB
# DEABCDEABC
# EABCDEABCD
